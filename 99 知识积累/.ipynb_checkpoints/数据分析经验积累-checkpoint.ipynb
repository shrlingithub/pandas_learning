# %% [markdown]
# # 如何构建指标体系

# %% [markdown]
# ## 什么是指标体系？
# ##### 指标体系是从不同维度梳理业务，把指标有系统地组织起来。简而言之，<span class="mark">指标体系=指标+体系</span>，所以一个指标不能叫指标体系，几个毫无关系的指标也不能叫指标体系。

# %% [markdown]
# ## 指标体系有什么用？
# ##### 监控业务情况；
# ##### 通过拆解指标寻找当前业务问题；
# ##### 评估业务可改进的地方，找出下一步工作的方向。

# %% [markdown]
# ## 如何建立指标体系？
# ![image.png](attachment:image.png)
# ### <span class="mark">明确部门KPI，找到合适的一级指标</span>
# ### <span class="burk"><span class="mark">了解业务运营情况，找到二级指标</span></span>
# ##### 有了一级指标以后，可以进一步将一级指标拆解为二级指标。具体如何拆解，要看业务是如何运营的。比如销售部门一般按地区运营，就可以从地区维度拆解。市场部门一般按用户运营，就可以从用户维度拆解。
# ![image-2.png](attachment:image-2.png)
# ### <span class="mark">梳理业务流程，找到三级指标</span>
# ![image-3.png](attachment:image-3.png)
# ### <span class="mark">通过报表监控指标，不断更新指标体系</span>
# ##### 前面步骤找到了一级指标、二级指标和三级指标，到这一步可以把这些指标制作到报表中，通过报表监控指标，不断更新指标体系。

# %% [markdown]
# ## 每个指标从3个方面确定统计口径
# ##### 指标含义：这个指标在业务上表示什么？
# ##### 指标定义：这个指标是怎么定义的？
# ##### 数据来源：从什么地方收集的原始数据？数据统计的时间范围是什么？

# %% [markdown]
# # 如何做数据分析
# ## 明确项目背景和需求
# ## 数据集摸底
# ## 数据清理
# ## 模型搭建
# ## 回归到项目发散

# %% [markdown]
# # 金字塔原理

# %% [markdown]
# ## 表达的逻辑

# %% [markdown]
# ### 为什么要用金字塔结构
#     采用金字塔结构方式，可以让读者更容易读懂。
#     大脑会自动将信息归纳到金字塔结构的各个部分，以便理解和记忆。
#     预先归纳到金字塔结构中的内容，更容易理解和记忆。
#
# ### <span class="mark">如何将思想组织成金字塔结构</span>
# -------------------------
# ● 归类分组，构建金字塔式思维结构
# ![image.png](attachment:image.png)
# -----------------------
# ● 自上而下，结论先行
# ![image-2.png](attachment:image-2.png)
# ------------------------
# ● 自下而上思考，总结概括
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### <span class="mark">金字塔内部的结构</span>
# ------------------------------------------------
# ●纵向关系
# ![image.png](attachment:image.png)
# ------------------------------------------------
# ●横向关系
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### <span class="mark">如何构建金字塔</span>
# ---------------------------------------------
# ●自上而下法
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ---------------------------------------------
# ●自下而上法
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 演绎推理与归纳推理
#     金字塔中的思想以3种方式互相关联，向上、向下、横向。 上一层思想是对下一层思想的总结和概括，下一层思想是对上一层思想的解释和支持。同一组思想之间存在特定的逻辑顺序，具体的顺序 取决于该组思想是演绎推理关系还是归纳推理关系。
# #### 演绎推理
# ##### 演绎推理是人们思考如何解决问题时候常用的方法。是从一个一般性的前提出发，经过不断推导，得出具体或者个别结论的过程。
# ##### 演绎推理是三段论，由一个大前提和一个小前提推到出来一个结论的论述方式。
# #### 演绎推理的步骤
# ![image.png](attachment:image.png)
# #### 演绎推理的步骤2
# ##### 1. 出现的问题或者存在的现象。
# ##### 2. 产生问题的根源。
# ##### 3. 解决问题的方案。（堵、疏、斩、 替）
# #### 归纳推理
# ##### 归纳推理使用的是创造性思维，今天归纳推理时候，需要发现若干事物的共性，然后将其归结在一起，加以说明。
# #### 归纳推理的步骤
# ##### 正确定义一组思想。
# ##### 找个一个能够表示改组思想共性的名字。
# ##### 样例
# ##### 日本商人，美国商人，德国商人。 三个名字共性名词是资本。
# ##### 日本商人正在增加对中国市场的投资。
# ##### 美国商人正在增加对中国市场的投资。
# ##### 德国商人正在增加对中国市场的投资。
# ##### 归纳： 资本正在增加对中国市场的投资。
# #### 演绎推理与归纳推理的区别
# ##### 演绎推理，第二点是对第一点的主语或者谓语的论述。
# ##### 归纳推理，同组中的思想具有某种共性。

# %% [markdown]
# ## 思考的逻辑

# %% [markdown]
# ### 应用逻辑顺序
# #### 时间顺序
# ##### 主题句是要达到的结果，表述思想的顺序与采取行动的顺序（第一步、第二步、第三步）是一致的。
# #### 结构顺序
# ##### 当你使用示意图、地图、图画或者照片想象某事物的顺序，比如组织结构图，关键成功因素等。
# ##### 将一个整体拆解为多个部分，拆解的原则是 mece原则
# #####     · 相互独立： 没有重叠
# #####     · 完全穷尽： 没有遗漏
# #### 程度顺序
# ##### 指明每组中的项目（思想、观点、问题等）是具有共同特性的，确保将所有具有该特性的项目列入一组，每组中，根据各个问题具有 特性的程度高低进行排序，先强后弱，先重要后次要，先紧急后一般。

# %% [markdown]
# ### 概况各组思想
# ##### 上一层的实际都是从下一层的思想中衍生、提炼、总结得出的。
# ##### 概括各组思想，需要确保分好的思想属于同一组，应抽象、提炼、概括其中的精华。
# #### 总结句避免使用缺乏思想的句子
# ##### 缺乏思想的语句会使你：掩盖思考不完整的事实。/ 错失进行逻辑思考和创造思考的机会。
# ##### 可以使用下面方法进行扩展思路：对其进一步的评论（演绎法）/ 找出与之类似的思想（归纳法）
# ##### 思想的表达方式是可以是行动性语句，就是告诉读者做什么事情；也可以是描述性语句， 即告诉读者关于某些事的情况。
# ##### 概括行动性思想（行动、流程、步骤）时，应说明采取后的结果（效果、预期目标）。/ 概括描述性思想（背景、信息）时，应说明这些思想所具有的共同点的含义（共同点的意义）。
# #### 说明采取行动的结果或目标
# ##### 步骤：
# ##### 在将各项行动（步骤、流程）联系起来之前，先用明确的语句描述各项行动（步骤、流程）。
# ##### 找出明确的因果关系组合，尽量将每一组中的行动、步骤控制在5个以下。
# ##### 直接从这些行动、步骤、流程来总结、概括行动的结果和目标。
# ![image.png](attachment:image.png)
# #### 找出各结论的共性
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 解决问题的逻辑

# %% [markdown]
# ### 界定问题
# ###### 问题是指你不喜欢某一个结果，想得到其他结果，也就是预期结果。 解决方案就是现状R1转化为目标R2的。
# ![image.png](attachment:image.png)
# #### 界定问题的框架
# ![image-2.png](attachment:image-2.png)
# #### 展开问题的各要素
# ![image-3.png](attachment:image-3.png)
# #### 发掘读者的疑问
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 结构化分析问题
# #### 结构化分析问题
# ![image.png](attachment:image.png)
# #### 从信息资料入手
# ![image-2.png](attachment:image-2.png)
# #### 设计诊断框架
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 相关分析
#     https://zhuanlan.zhihu.com/p/396580986

# %% [markdown]
# ## 分析结论
#     ● 是否相关（需进行假设检验，观察相关性是否显著）；
#     ● 相关方向（正相关/负相关）
#     ● 相关程度（大小）

# %% [markdown]
# ## 数据类型
#     ● 连续变量
#     ● 二分类变量（只有两个类别的无序分类变量）
#     ● 有序分类变量（若变量类别之间定距，则可以进行赋值操作，将其看为连续变量；但通常情况下还是对类别进行分析）
#     ● 无序分类变量
#
#     注：对于可能存在相关关系的两个变量来说，需要注意是否区分自变量和因变量。
#     1. 区分自变量和因变量：可以明确认为，变量A的变化导致了变量B的变化；
#     2.不区分自变量和因变量：变量A的变化导致了变量B的变化，变量B的变化导致了变量 A的变化，这两种说法都可

# %% [markdown]
# ## 分析方法总结（两个变量）

# %% [markdown]
# ### 连续变量+连续变量
#     方法：Pearson相关系数（只反映线性相关程度）
# ###### Pearson相关系数
#     1.适用条件
#         ● 两个变量分别服从正态分布；（当数据量够大时，譬如 n>30 ，根据中心极限定理，可以假定服从正态分布）
#         ● 两个变量的标准差不为0（通常都满足）
#     2. 计算方法
# ###### $$ ρ=\frac{E[(X-μ_x)(Y-μ_y)]}{μ_xμ_y}=\frac{\sum(x-\bar x)(y-\bar y)}{\sqrt{\sum {(x-\bar x)}^2}\sqrt{\sum {(y-\bar y)}^2}} $$
#     3. 显著性检验,通常使用 t 检验来验证Pearson相关系数的显著性。
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 连续变量+二分类变量
#     方法：Point-biserial相关系数（Pearson相关的一种特殊形式，只反映线性相关）
# ###### Point-biserial相关系数
#     1. 计算方法
# ###### $$ r_{pb}=\frac{\overline Y_1-\overline Y_0}{s_{n-1}}\sqrt{\frac{n_1n_0}{n(n-1)}}=\frac{\overline Y_1-\overline Y_0}{s_{n}}\sqrt{\frac{n_1n_0}{n^2}} $$
# ###### ![image.png](attachment:image.png)
#     2. 显著性检验,使用 t 检验来验证Point-biserial相关系数的显著性
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 连续变量+有序分类变量
#     方法：Spearman相关（将连续变量视为有序分类变量，见下文 有序分类变量+有序分类变量）

# %% [markdown]
# ### 连续变量+无序分类变量
#     方法（通常连续变量为因变量）：
#     1. 单因素方差分析（参数统计方法，适用于正态数据）
#     2. Kruskal-Wallis检验（非参数统计方法，适用于偏态数据）

# %% [markdown]
# #### 单因素方差分析
# ![image.png](attachment:image.png)
# #### Kruskal-Wallis 检验
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 二分类变量+二分类变量
#     方法：
#         1. 区分自变量和因变量：优势比（OR，odds ratio）；
#         2. 不区分自变量和因变量：卡方检验（可结合Cramer's V系数来显示相关程度）、Fisher精确检验； （见下文）
#         3. Cochran-Mantel-Haenszel 卡方检验（CMH检验）（排除混杂变量的影响来检验两个变量之间的相关性）
# ###### odds ratio（优势比）
# ![image.png](attachment:image.png)
# ###### Cochran-Mantel-Haenszel 卡方检验（CMH检验）
# ######

# %% [markdown]
# ## Q&A
# ###### Q1：相关与回归的区别？
#     表达变量之间的依存情况有两种方式：相关关系和回归关系（函数关系）。
#
#     回归关系是一种确定关系，通过一个或多个变量（自变量）的取值能够得到另一个变量（因变量）的取值，可以通过回归方程（函数方程）实现
#
#     相关关系不是确定关系，当一个（多个）变量的取值发生变化时，与它（它们）相关的变量的取值也会发生变化，但变化值不是确定的数值。
#
#     因此，在数据分析中，一般先做相关关系的分析，待相关关系清楚以后，再进一步确定不同变量之间的函数关系（回归关系）。
#
# ###### Q2：相关系数不显著就说明不相关？
#     对于 Pearson相关系数 这样的参数统计方法来说，计算的通常是线性相关系数，即只能反映变量之间的线性相关关系。若该类相关系数不显著，只能说明不存在线性相关关系，但可能还存在非线性相关关系。此时，可以通过绘制散点图查看变量之间的大致关系，再进行合适的数据转换（对数转换、指数转换、平方转换、平方根转换等），对转换后的数据再进行线性相关分析。
#
#     对于 Spearman相关系数 这样的非参数统计方法来说，计算的是变量之间的联系情况（也包括非线性相关关系）。若该类相关系数不显著，则说明变量之间不存在相关关系。
#
# ###### Q3：相关性显著，但相关系数很小？
#     可能的原因：异常值
#
# ###### Q4：多个变量之间的相关关系如何分析？
#     要同时研究多个变量之间的相关关系，这种情况通常出现在线性回归模型里，即同时研究多个自变量和因变量之间的相关关系（复相关关系、偏相关关系）。
#
#     在实际应用中，一个变量的变化往往会受到多个变量的影响，而非完全的二元相关关系，因此这就使得二元变量相关系数不能真实反映两个变量间的线性相关程度。因此当两个变量的取值受到其它变量影响时，可以利用偏相关分析对其它变量进行控制，以输出控制其它变量影响后的相关系数，这就是偏相关分析。

# %% [markdown]
# ## 总结
#     在分析变量（两个变量）之间的相关关系时，建议可按照如下步骤逐一进行。
#         （1）确定变量类型。根据两个变量的数据类型，选择合适的分析方法。
#         （2）画散点图。若选择的是 Pearson相关系数类，则可以先画散点图查看变量间的大致情况。
#         （3）验证适用条件。验证变量是否满足所选方法的适用条件。
#         （4）假设检验并计算。进行假设检验，判断相关性是否显著，并根据需要计算对应的相关系数取值。
